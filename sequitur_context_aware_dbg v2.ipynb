# %%
import unittest

# %% [markdown]
# *   variant reads (sort by coverage?)

# %%
def generate_sequence(n):
  import random

  bases = ['a','g','c','t']
  seq = ''
  for i in range(n):
    seq += bases[random.randint(0,3)]
  return seq

def chop_sequence(sequence,min_len=3,max_len=15,min_overlap=3):
  import random

  start = 0
  end = max(random.randint(start,max_len),min_len)
  chop = [sequence[start:end]]
  while end < len(sequence):
    start = random.randint(start + 1,end - min_overlap)
    end = max(random.randint(start,start + max_len),start + min_len)
    chop += [sequence[start:end]]
  return chop

# %%
ref = "Fresh out of college, Barry the Bee (Jerry Seinfeld) finds the prospect of working with honey uninspiring. He flies outside the hive for the first time and talks to a human (Renée Zellweger), breaking a cardinal rule of his species. Barry learns that humans have been stealing and eating honey for centuries, and he realizes that his true calling is to obtain justice for his kind by suing humanity for theft." #generate_sequence(200)
reads = chop_sequence(ref,9,18,8)
import random
print(ref)
print(reads)
# random.shuffle(reads)
# Out:
# Fresh out of college, Barry the Bee (Jerry Seinfeld) finds the prospect of working with honey uninspiring. He flies outside the hive for the first time and talks to a human (Renée Zellweger), breaking a cardinal rule of his species. Barry learns that humans have been stealing and eating honey for centuries, and he realizes that his true calling is to obtain justice for his kind by suing humanity for theft.
# ['Fresh out', 'resh out ', 'esh out of colleg', 'of college,', 'f college, Barr', ' college, Barry', 'lege, Bar', 'ege, Barry the Bee', 'arry the Bee ', 'the Bee (', 'he Bee (J', 'e Bee (Jerry ', 'ee (Jerry S', '(Jerry Sein', 'rry Seinf', 'ry Seinfe', 'y Seinfel', ' Seinfeld) finds', 'eld) find', 'ld) finds the pros', 'the prosp', 'he prospe', 'e prospect o', ' prospect of', 'spect of working w', ' working ', 'working with', 'orking wi', 'rking wit', 'king with hone', 'with honey uninspi', 'th honey ', 'h honey u', ' honey un', 'honey unins', 'ney unins', 'ey uninspiring. H', 'ninspiring. He', 'ring. He ', 'ing. He f', 'ng. He flies out', 'He flies outs', 'lies outside the h', 'de the hive for', 'e the hive fo', ' hive for the f', 'hive for the firs', 'e for the', ' for the ', 'for the f', 'or the fi', 'r the fir', ' the firs', 'the first', 'he first time an', ' first ti', 'first time and t', 'ime and t', 'me and tal', 'e and tal', ' and talk', 'and talks', 'nd talks ', 'd talks to a h', 'lks to a h', 's to a human (Re', ' a human (Renée Ze', 'n (Renée ', ' (Renée Zel', '(Renée Ze', 'Renée Zellweger),', 'enée Zell', 'née Zellw', 'ée Zellweger), b', 'e Zellwege', ' Zellwege', 'Zellweger), b', 'ellweger)', 'llweger),', 'lweger), bre', 'er), brea', 'r), break', '), breaking ', 'reaking a cardin', 'ing a car', 'ng a card', 'g a cardinal ru', ' cardinal rule o', 'nal rule of', ' rule of hi', 'le of his', 'e of his spec', ' his spec', 'his species. Bar', 'cies. Bar', 'ies. Barry learn', 'ry learns that h', 'ns that humans', 's that humans ha', 'humans have been s', 'umans hav', 'mans have', 'ans have ', 'ns have been steal', 've been s', 'e been stealing ', 'tealing a', 'ealing an', 'aling and eati', 'ng and eatin', ' and eating honey', 'ating honey fo', 'ing honey', 'ng honey for cent', 'g honey for ', 'ney for c', 'ey for ce', 'y for centur', 'or centuri', ' centurie', 'centuries', 'enturies,', 'nturies, and he re', 'uries, an', 'ries, and he reali', 'ies, and he', ', and he re', 'and he re', 'nd he rea', 'd he real', ' he reali', 'he realiz', 'e realizes that', 'zes that his tru', 't his tru', ' his true', 'his true calli', 'ue calling i', 'calling is to obt', 'ing is to obtai', ' to obtain just', 'tain just', 'ain justi', 'in justic', 'n justice for hi', 'e for his', ' for his kind by', 's kind by suing hu', 'suing huma', 'ing human', 'ng humanity fo', ' humanity f', 'umanity for th', 'y for the', ' for thef', 'for theft', 'or theft.']

# %%
ref = "The sly brown fox jumps swiftly over the lazy dog"
reads = chop_sequence(ref,6,11)
import random
random.shuffle(reads)
print(ref)
print(reads)
# Out:
# The sly brown fox jumps swiftly over the lazy dog
# ['n fox ju', 'jumps sw', 'he laz', ' sly b', ' over ', 'tly ov', 'er the', 'lazy dog', 'r the lazy', 'wiftly', ' jumps', 'rown fox ju', 's swif', 'The sly bro', ' brown', 'y brow']

# %%
class Read:
  def __init__ (self,read,k_min=3):
    self.read = read
    self.k_min = k_min

  def __repr__(self):
    return self.read

  def __getitem__(self,key):
    return self.read[key]

  def __len__(self):
    return len(self.read)

  def partition(self,sep):
    return self.read.partition(sep)
  
  def startswith(self,key):
    return self.read.startswith(key)

  def endswith(self,key):
    return self.read.endswith(key)

  def find(self,key):
    return self.read.find(key)

  def __contains__(self,item):
    return item in self.read

  def get_all_partitions(self,root):
    index = 0
    for c in range(self.read.count(root)):
      index = self.read.find(root,index)
      part = list(self.read[index:].partition(root))
      part[0] += self.read[:index]
      yield part, index
      index += len(root)

  def connection_strength(self,other,root,index=0):
    p2 = list(other.read[other.read.find(root,index):].partition(root))
    p2[0] += other.read[:other.read.find(root,index)]
    max_pre = max_suf = 0
    for p1 in self.get_all_partitions(root):
      min_pre = min(len(p1[0][0]),len(p2[0]))
      min_suf = min(len(p1[0][2]),len(p2[2]))
      if min_pre == 0 and min_suf == 0: continue
      if self.read[p1[1]-min_pre:p1[1]+len(root)+min_suf] == other.read[other.read.find(root,index)-min_pre:other.read.find(root,index)+len(root)+min_suf]:
         max_pre = max(min_pre,max_pre)
         max_suf = max(min_suf,max_suf)
    return (max_pre + max_suf,max_pre, max_suf)

  def is_continuous_with(self,other,root,index=0):
    p2 = list(other.read[other.read.find(root,index):].partition(root))
    p2[0] += other.read[:other.read.find(root,index)]
    for p1 in self.get_all_partitions(root):
      min_pre = min(len(p1[0][0]),len(p2[0]))
      min_suf = min(len(p1[0][2]),len(p2[2]))
      # if min_pre == 0 and min_suf == 0: continue
      if self.read[p1[1]-min_pre:p1[1]+len(root)+min_suf] == other.read[other.read.find(root,index)-min_pre:other.read.find(root,index)+len(root)+min_suf]: return True
    return False

  def continues_to(self,other,root):
    return self.read.partition(root)[0].endswith(other.read.partition(root)[0])
  
  def continues_from(self,other,root):
    return self.read.partition(root)[2].startswith(other.read.partition(root)[2])

# %%
class Segment:
  def __init__(self,prefix,root,suffix,read):
    self.root = root
    self.read = read
    self.prefix = prefix
    self.suffix = suffix
    
  def __repr__(self):
    return '{}{}{}'.format(self.prefix.root + ' -> ' if self.prefix else '',self.root,' -> ' + self.suffix.root if self.suffix else '')

  def __hash__(self):
    return hash(self.root)

  def __eq__(self,other):
    return self.root == other.root

  def __len__(self):
    return len(self.root)

  def __getitem__(self,key):
    return self.root[key]

# %%
# v2
class Sequitur:
  def __init__(self,reads,k_min=3):
    self.k_min = k_min
    self.reads = list(map(Read,reads))
    self.transitions = {}
    self.ends = {}
    self.seq = ''
    for read in self.reads:
      if read.read == 'Barry the Bee (':
        print()
      cont = False
      seg = None
      i = 1
      l = self.k_min
      # find starting point for read
      if len(self.transitions) > 0:
        for r in set(map(len,self.transitions.keys())):
          a = 0
          # while read[a:r+a] in self.transitions and self.transitions[read[a:r+a]].prefix and self.transitions[read[a:r+a]].prefix.read.is_continuous_with(read,read[a:r+a]):
          while read[a:r+a] in self.transitions and self.transitions[read[a:r+a]].read.is_continuous_with(read,read[a:r+a]):
            a += 1
          if a > 0:
            a -= 1
            curr = self.transitions[read[a:r+a]]
            while curr.suffix and curr.suffix.read.is_continuous_with(read,curr.suffix.root):
              curr = curr.suffix
            if curr.suffix and not read.endswith(curr.root):
              # check for stronger suffix connection specifically
              # when would a strong prefix connection matter?
              new_conn = curr.read.connection_strength(read,curr.root)
              old_conn = curr.read.connection_strength(curr.suffix.read,curr.root)
              if new_conn[0] >= old_conn[0]:
                if new_conn[1] >= old_conn[1]:
                  print()
                if new_conn[2] >= old_conn[2]:
                  seg = curr
                  curr.suffix.prefix = None
                  curr.suffix = None
                  l = read.find(curr.root) + len(curr.root)
                  i = read.find(curr.root) + 1
                break
              elif new_conn[0] < 2:
                continue
              else:
                cont = True
                break
            elif curr.suffix and read.endswith(curr.root):
              cont = True
              break
            else: 
              seg = curr
              # seg.read = read
              l = read.find(curr.root) + len(curr.root)
              i = read.find(curr.root) + 1
              break
      if cont:
        continue
      if not seg:
        a = 0
        while read[:self.k_min+a] in self.transitions:
          a += 1
        seg = Segment(None,read[:self.k_min+a],None,read)
        self.transitions[read[:self.k_min+a]] = seg
      s = 0
      p = 0
      while l < len(read):
        if read[i+p:i+p+self.k_min+s] in self.transitions:
          if self.transitions[read[i+p:i+p+self.k_min+s]].read != read\
            and self.transitions[read[i+p:i+p+self.k_min+s]].read.is_continuous_with(read,read[i+p:i+p+self.k_min+s],i+p):
            self.transitions[read[i+p:i+p+self.k_min+s]].prefix = seg
            seg.suffix = self.transitions[read[i+p:i+p+self.k_min+s]]
            curr = self.transitions[read[i+p:i+p+self.k_min+s]]
            while curr.suffix and curr.suffix.read.is_continuous_with(read,curr.suffix.root):
              curr = curr.suffix
            if curr.suffix and not read.endswith(curr.root):
              if curr.read.connection_strength(read,curr.root)[0] > curr.read.connection_strength(curr.suffix.read,curr.root)[0]:
                seg = curr
                curr.suffix.prefix = None
                curr.suffix = None
                l = read.find(curr.root) + len(curr.root)
                i = read.find(curr.root) + 1
                continue
            elif curr.suffix and read.endswith(curr.root):
              break
            seg = curr
            l = read.find(curr.root) + len(curr.root)
            i = read.find(curr.root) + 1
            continue
          if i + abs(p) + s + self.k_min < len(read):
            s += 1
          else:
            p -= 1
            s += 1
            self.transitions.pop(seg.root)
            seg.prefix.suffix = None
            seg = seg.prefix
        else:
          self.transitions[read[i+p:i+p+self.k_min+s]] = Segment(seg,read[i+p:i+p+self.k_min+s],None,read)
          seg.suffix = self.transitions[read[i+p:i+p+self.k_min+s]]
          seg = self.transitions[read[i+p:i+p+self.k_min+s]]
          l = read.find(read[i+p:i+p+self.k_min+s]) + len(read[i+p:i+p+self.k_min+s])
          i = read.find(read[i+p:i+p+self.k_min+s]) + 1
          s = 0
          p = 0

  def __repr__(self):
    return str(self.transitions)

  def construct(self):
    self.seq = 'Fre'
    curr = self.transitions[self.seq].suffix
    while curr:
      self.seq += curr.root.partition(self.seq[-(self.k_min-1):])[2]
      curr = curr.suffix
    return self.seq

# %%
seq = Sequitur(reads)

# %%
seq.transitions
# Out:
# {'Fre': Fre -> res,
#  'res': Fre -> res -> esh,
#  'esh': res -> esh -> sh ,
#  'sh ': esh -> sh  -> h o,
#  'h o': sh  -> h o ->  ou,
#  ' ou': h o ->  ou -> out,
#  'out':  ou -> out -> ut ,
#  'ut ': out -> ut  -> t o,
#  't o': ut  -> t o ->  of,
#  ' of': t o ->  of -> of ,
#  'of ':  of -> of  -> f c,
#  'f c': of  -> f c ->  co,
#  ' co': f c ->  co -> col,
#  'col':  co -> col -> oll,
#  'oll': col -> oll -> lle,
#  'lle': oll -> lle -> leg,
#  'leg': lle -> leg -> ege,
#  'ege': leg -> ege -> ge,,
#  'ge,': ege -> ge, -> e, ,
#  'e, ': ge, -> e,  -> , B,
#  ', B': e,  -> , B ->  Ba,
#  ' Ba': , B ->  Ba -> Bar,
#  'Bar':  Ba -> Bar -> arr,
#  'arr': Bar -> arr -> rry,
#  'rry': arr -> rry -> ry ,
#  'ry ': rry -> ry  -> y t,
#  'y t': ry  -> y t ->  th,
#  ' th': y t ->  th -> the,
#  'the':  th -> the -> he ,
#  'he ': the -> he  -> e B,
#  'e B': he  -> e B ->  Be,
#  ' Be': e B ->  Be -> Bee,
#  'Bee':  Be -> Bee -> ee ,
#  'ee ': Bee -> ee  -> e (,
#  'e (': ee  -> e ( ->  (J,
#  ' (J': e ( ->  (J -> (Je,
#  '(Je':  (J -> (Je -> Jer,
#  'Jer': (Je -> Jer -> err,
#  'err': Jer -> err -> rry ,
#  'rry ': err -> rry  -> ry S,
#  'ry S': rry  -> ry S -> y S,
#  'y S': ry S -> y S ->  Se,
#  ' Se': y S ->  Se -> Sei,
#  'Sei':  Se -> Sei -> ein,
#  'ein': Sei -> ein -> inf,
#  'inf': ein -> inf -> nfe,
#  'nfe': inf -> nfe -> fel,
#  'fel': nfe -> fel -> eld,
#  'eld': fel -> eld -> ld),
#  'ld)': eld -> ld) -> d) ,
#  'd) ': ld) -> d)  -> ) f,
#  ') f': d)  -> ) f ->  fi,
#  ' fi': ) f ->  fi -> fin,
#  'fin':  fi -> fin -> ind,
#  'ind': fin -> ind -> nds,
#  'nds': ind -> nds -> ds ,
#  'ds ': nds -> ds  -> s t,
#  's t': ds  -> s t ->  the,
#  ' the': s t ->  the -> the ,
#  'the ':  the -> the  -> he p,
#  'he p': the  -> he p -> e p,
#  'e p': he p -> e p ->  pr,
#  ' pr': e p ->  pr -> pro,
#  'pro':  pr -> pro -> ros,
#  'ros': pro -> ros -> osp,
#  'osp': ros -> osp -> spe,
#  'spe': osp -> spe -> pec,
#  'pec': spe -> pec -> ect,
#  'ect': pec -> ect -> ct o,
#  'ct o': ect -> ct o -> t of,
#  't of': ct o -> t of ->  of ,
#  ' of ': t of ->  of  -> of w,
#  'of w':  of  -> of w -> f w,
#  'f w': of w -> f w ->  wo,
#  ' wo': f w ->  wo -> wor,
#  'wor':  wo -> wor -> ork,
#  'ork': wor -> ork -> rki,
#  'rki': ork -> rki -> kin,
#  'kin': rki -> kin -> ing,
#  'ing': kin -> ing -> ng ,
#  'ng ': ing -> ng  -> g w,
#  'g w': ng  -> g w ->  wi,
#  ' wi': g w ->  wi -> wit,
#  'wit':  wi -> wit -> ith,
#  'ith': wit -> ith -> th ,
#  'th ': ith -> th  -> h h,
#  'h h': th  -> h h ->  ho,
#  ' ho': h h ->  ho -> hon,
#  'hon':  ho -> hon -> one,
#  'one': hon -> one -> ney,
#  'ney': one -> ney -> ey ,
#  'ey ': ney -> ey  -> y u,
#  'y u': ey  -> y u ->  un,
#  ' un': y u ->  un -> uni,
#  'uni':  un -> uni -> nin,
#  'nin': uni -> nin -> ins,
#  'ins': nin -> ins -> nsp,
#  'nsp': ins -> nsp -> spi,
#  'spi': nsp -> spi -> pir,
#  'pir': spi -> pir -> iri,
#  'iri': pir -> iri -> rin,
#  'rin': iri -> rin -> ing.,
#  'ing.': rin -> ing. -> ng.,
#  'ng.': ing. -> ng. -> g. ,
#  'g. ': ng. -> g.  -> . H,
#  '. H': g.  -> . H ->  He,
#  ' He': . H ->  He -> He ,
#  'He ':  He -> He  -> e f,
#  'e f': He  -> e f ->  fl,
#  ' fl': e f ->  fl -> fli,
#  'fli':  fl -> fli -> lie,
#  'lie': fli -> lie -> ies,
#  'ies': lie -> ies -> es ,
#  'es ': ies -> es  -> s o,
#  's o': es  -> s o ->  out,
#  ' out': s o ->  out -> outs,
#  'outs':  out -> outs -> uts,
#  'uts': outs -> uts -> tsi,
#  'tsi': uts -> tsi -> sid,
#  'sid': tsi -> sid -> ide,
#  'ide': sid -> ide -> de ,
#  'de ': ide -> de  -> e t,
#  'e t': de  -> e t ->  the ,
#  ' the ': e t ->  the  -> the h,
#  'the h':  the  -> the h -> he h,
#  'he h': the h -> he h -> e h,
#  'e h': he h -> e h ->  hi,
#  ' hi': e h ->  hi -> hiv,
#  'hiv':  hi -> hiv -> ive,
#  'ive': hiv -> ive -> ve ,
#  've ': ive -> ve  -> e fo,
#  'e fo': ve  -> e fo ->  fo,
#  ' fo': e fo ->  fo -> for,
#  'for':  fo -> for -> or ,
#  'or ': for -> or  -> r t,
#  'r t': or  -> r t ->  the f,
#  ' the f': r t ->  the f -> the f,
#  'the f':  the f -> the f -> he f,
#  'he f': the f -> he f -> e fi,
#  'e fi': he f -> e fi ->  fir,
#  ' fir': e fi ->  fir -> fir,
#  'fir':  fir -> fir -> irs,
#  'irs': fir -> irs -> rst,
#  'rst': irs -> rst -> st ,
#  'st ': rst -> st  -> t t,
#  't t': st  -> t t ->  ti,
#  ' ti': t t ->  ti -> tim,
#  'tim':  ti -> tim -> ime,
#  'ime': tim -> ime -> me ,
#  'me ': ime -> me  -> e a,
#  'e a': me  -> e a ->  an,
#  ' an': e a ->  an -> and,
#  'and':  an -> and -> nd ,
#  'nd ': and -> nd  -> d t,
#  'd t': nd  -> d t ->  ta,
#  ' ta': d t ->  ta -> tal,
#  'tal':  ta -> tal -> alk,
#  'alk': tal -> alk -> lks,
#  'lks': alk -> lks -> ks ,
#  'ks ': lks -> ks  -> s to,
#  's to': ks  -> s to ->  to,
#  ' to': s to ->  to -> to ,
#  'to ':  to -> to  -> o a,
#  'o a': to  -> o a ->  a ,
#  ' a ': o a ->  a  -> a h,
#  'a h':  a  -> a h ->  hu,
#  ' hu': a h ->  hu -> hum,
#  'hum':  hu -> hum -> uma,
#  'uma': hum -> uma -> man,
#  'man': uma -> man -> an ,
#  'an ': man -> an  -> n (,
#  'n (': an  -> n ( ->  (R,
#  ' (R': n ( ->  (R -> (Re,
#  '(Re':  (R -> (Re -> Ren,
#  'Ren': (Re -> Ren -> ené,
#  'ené': Ren -> ené -> née,
#  'née': ené -> née -> ée ,
#  'ée ': née -> ée  -> e Z,
#  'e Z': ée  -> e Z ->  Ze,
#  ' Ze': e Z ->  Ze -> Zel,
#  'Zel':  Ze -> Zel -> ell,
#  'ell': Zel -> ell -> llw,
#  'llw': ell -> llw -> lwe,
#  'lwe': llw -> lwe -> weg,
#  'weg': lwe -> weg -> eger,
#  'eger': weg -> eger -> ger,
#  'ger': eger -> ger -> er),
#  'er)': ger -> er) -> r),,
#  'r),': er) -> r), -> ), ,
#  '), ': r), -> ),  -> , b,
#  ', b': ),  -> , b ->  br,
#  ' br': , b ->  br -> bre,
#  'bre':  br -> bre -> rea,
#  'rea': bre -> rea -> eak,
#  'eak': rea -> eak -> aki,
#  'aki': eak -> aki -> king,
#  'king': aki -> king -> ing ,
#  'ing ': king -> ing  -> ng a,
#  'ng a': ing  -> ng a -> g a,
#  'g a': ng a -> g a ->  a c,
#  ' a c': g a ->  a c -> a c,
#  'a c':  a c -> a c ->  ca,
#  ' ca': a c ->  ca -> car,
#  'car':  ca -> car -> ard,
#  'ard': car -> ard -> rdi,
#  'rdi': ard -> rdi -> din,
#  'din': rdi -> din -> ina,
#  'ina': din -> ina -> nal,
#  'nal': ina -> nal -> al ,
#  'al ': nal -> al  -> l r,
#  'l r': al  -> l r ->  ru,
#  ' ru': l r ->  ru -> rul,
#  'rul':  ru -> rul -> ule,
#  'ule': rul -> ule -> le ,
#  'le ': ule -> le  -> e of,
#  'e of': le  -> e of ->  of h,
#  ' of h': e of ->  of h -> of h,
#  'of h':  of h -> of h -> f hi,
#  'f hi': of h -> f hi ->  his,
#  ' his': f hi ->  his -> his,
#  'his':  his -> his -> is ,
#  'is ': his -> is  -> s s,
#  's s': is  -> s s ->  sp,
#  ' sp': s s ->  sp -> spec,
#  'spec':  sp -> spec -> peci,
#  'peci': spec -> peci -> eci,
#  'eci': peci -> eci -> cie,
#  'cie': eci -> cie -> ies.,
#  'ies.': cie -> ies. -> es.,
#  'es.': ies. -> es. -> s. ,
#  's. ': es. -> s.  -> . B,
#  '. B': s.  -> . B ->  Bar,
#  ' Bar': . B ->  Bar -> Barr,
#  'Barr':  Bar -> Barr -> arry,
#  'arry': Barr -> arry -> rry l,
#  'rry l': arry -> rry l -> ry l,
#  'ry l': rry l -> ry l -> y l,
#  'y l': ry l -> y l ->  le,
#  ' le': y l ->  le -> lea,
#  'lea':  le -> lea -> ear,
#  'ear': lea -> ear -> arn,
#  'arn': ear -> arn -> rns,
#  'rns': arn -> rns -> ns ,
#  'ns ': rns -> ns  -> s th,
#  's th': ns  -> s th ->  tha,
#  ' tha': s th ->  tha -> tha,
#  'tha':  tha -> tha -> hat,
#  'hat': tha -> hat -> at ,
#  'at ': hat -> at  -> t h,
#  't h': at  -> t h ->  hum,
#  ' hum': t h ->  hum -> huma,
#  'huma':  hum -> huma -> uman,
#  'uman': huma -> uman -> mans,
#  'mans': uman -> mans -> ans,
#  'ans': mans -> ans -> ns h,
#  'ns h': ans -> ns h -> s h,
#  's h': ns h -> s h ->  ha,
#  ' ha': s h ->  ha -> hav,
#  'hav':  ha -> hav -> ave,
#  'ave': hav -> ave -> ve b,
#  've b': ave -> ve b -> e b,
#  'e b': ve b -> e b ->  be,
#  ' be': e b ->  be -> bee,
#  'bee':  be -> bee -> een,
#  'een': bee -> een -> en ,
#  'en ': een -> en  -> n s,
#  'n s': en  -> n s ->  st,
#  ' st': n s ->  st -> ste,
#  'ste':  st -> ste -> tea,
#  'tea': ste -> tea -> eal,
#  'eal': tea -> eal -> ali,
#  'ali': eal -> ali -> ling ,
#  'ling ': ali -> ling  -> ing a,
#  'ing a': ling  -> ing a -> ng an,
#  'ng an': ing a -> ng an -> g an,
#  'g an': ng an -> g an ->  and,
#  ' and': g an ->  and -> and ,
#  'and ':  and -> and  -> nd e,
#  'nd e': and  -> nd e -> d e,
#  'd e': nd e -> d e ->  ea,
#  ' ea': d e ->  ea -> eat,
#  'eat':  ea -> eat -> ati,
#  'ati': eat -> ati -> tin,
#  'tin': ati -> tin -> ing h,
#  'ing h': tin -> ing h -> ng h,
#  'ng h': ing h -> ng h -> g h,
#  'g h': ng h -> g h ->  hon,
#  ' hon': g h ->  hon -> hone,
#  'hone':  hon -> hone -> oney,
#  'oney': hone -> oney -> ney ,
#  'ney ': oney -> ney  -> ey f,
#  'ey f': ney  -> ey f -> y fo,
#  'y fo': ey f -> y fo ->  for,
#  ' for': y fo ->  for -> for ,
#  'for ':  for -> for  -> or c,
#  'or c': for  -> or c -> r c,
#  'r c': or c -> r c ->  ce,
#  ' ce': r c ->  ce -> cen,
#  'cen':  ce -> cen -> ent,
#  'ent': cen -> ent -> ntu,
#  'ntu': ent -> ntu -> tur,
#  'tur': ntu -> tur -> uri,
#  'uri': tur -> uri -> ries,
#  'ries': uri -> ries -> ies,,
#  'ies,': ries -> ies, -> es,,
#  'es,': ies, -> es, -> s, ,
#  's, ': es, -> s,  -> , a,
#  ', a': s,  -> , a ->  and ,
#  ' and ': , a ->  and  -> and h,
#  'and h':  and  -> and h -> nd h,
#  'nd h': and h -> nd h -> d h,
#  'd h': nd h -> d h ->  he,
#  ' he': d h ->  he -> he r,
#  'he r':  he -> he r -> e r,
#  'e r': he r -> e r ->  re,
#  ' re': e r ->  re -> real,
#  'real':  re -> real -> eali,
#  'eali': real -> eali -> aliz,
#  'aliz': eali -> aliz -> liz,
#  'liz': aliz -> liz -> ize,
#  'ize': liz -> ize -> zes,
#  'zes': ize -> zes -> es t,
#  'es t': zes -> es t -> s tha,
#  's tha': es t -> s tha ->  that,
#  ' that': s tha ->  that -> that,
#  'that':  that -> that -> hat ,
#  'hat ': that -> hat  -> at h,
#  'at h': hat  -> at h -> t hi,
#  't hi': at h -> t hi ->  his ,
#  ' his ': t hi ->  his  -> his ,
#  'his ':  his  -> his  -> is t,
#  'is t': his  -> is t -> s tr,
#  's tr': is t -> s tr ->  tr,
#  ' tr': s tr ->  tr -> tru,
#  'tru':  tr -> tru -> rue,
#  'rue': tru -> rue -> ue ,
#  'ue ': rue -> ue  -> e c,
#  'e c': ue  -> e c ->  cal,
#  ' cal': e c ->  cal -> cal,
#  'cal':  cal -> cal -> all,
#  'all': cal -> all -> lli,
#  'lli': all -> lli -> lin,
#  'lin': lli -> lin -> ing i,
#  'ing i': lin -> ing i -> ng i,
#  'ng i': ing i -> ng i -> g i,
#  'g i': ng i -> g i ->  is,
#  ' is': g i ->  is -> is to,
#  'is to':  is -> is to -> s to ,
#  's to ': is to -> s to  ->  to ,
#  ' to ': s to  ->  to  -> to o,
#  'to o':  to  -> to o -> o o,
#  'o o': to o -> o o ->  ob,
#  ' ob': o o ->  ob -> obt,
#  'obt':  ob -> obt -> bta,
#  'bta': obt -> bta -> tai,
#  'tai': bta -> tai -> ain,
#  'ain': tai -> ain -> in ,
#  'in ': ain -> in  -> n j,
#  'n j': in  -> n j ->  ju,
#  ' ju': n j ->  ju -> jus,
#  'jus':  ju -> jus -> ust,
#  'ust': jus -> ust -> sti,
#  'sti': ust -> sti -> tic,
#  'tic': sti -> tic -> ice,
#  'ice': tic -> ice -> ce ,
#  'ce ': ice -> ce  -> e for,
#  'e for': ce  -> e for ->  for ,
#  ' for ': e for ->  for  -> for h,
#  'for h':  for  -> for h -> or h,
#  'or h': for h -> or h -> r hi,
#  'r hi': or h -> r hi ->  his k,
#  ' his k': r hi ->  his k -> his k,
#  'his k':  his k -> his k -> is k,
#  'is k': his k -> is k -> s k,
#  's k': is k -> s k ->  ki,
#  ' ki': s k ->  ki -> kind,
#  'kind':  ki -> kind -> ind ,
#  'ind ': kind -> ind  -> nd b,
#  'nd b': ind  -> nd b -> d b,
#  'd b': nd b -> d b ->  by,
#  ' by': d b ->  by -> by ,
#  'by ':  by -> by  -> y s,
#  'y s': by  -> y s ->  su,
#  ' su': y s ->  su -> sui,
#  'sui':  su -> sui -> uin,
#  'uin': sui -> uin -> ing hu,
#  'ing hu': uin -> ing hu -> ng hu,
#  'ng hu': ing hu -> ng hu -> g hu,
#  'g hu': ng hu -> g hu ->  huma,
#  ' huma': g hu ->  huma -> human,
#  'human':  huma -> human -> umani,
#  'umani': human -> umani -> mani,
#  'mani': umani -> mani -> ani,
#  'ani': mani -> ani -> nit,
#  'nit': ani -> nit -> ity,
#  'ity': nit -> ity -> ty fo,
#  'ty fo': ity -> ty fo -> y f,
#  'y f': ty fo -> y f ->  for t,
#  ' for t': y f ->  for t -> for t,
#  'for t':  for t -> for t -> or t,
#  'or t': for t -> or t -> r the,
#  'r the': or t -> r the ->  thef,
#  ' thef': r the ->  thef -> thef,
#  'thef':  thef -> thef -> hef,
#  'hef': thef -> hef -> eft,
#  'eft': hef -> eft -> ft.,
#  'ft.': eft -> ft.}

# %%
seq.construct()
# Out:
# 'Fresh out of college, Barry the Bee (Jerry Seinfeld) finds the prospect of working with honey uninspiring. He flies outside the hive for the first time and talks to a human (Renée Zellweger), breaking a cardinal rule of his species. Barry learns that humans have been stealing and eating honey for centuries, and he realizes that his true calling is to obtain justice for his kind by suing humanity for theft.'

# %%
seq.transitions['y th'].read
# Out:
#  Barry th
